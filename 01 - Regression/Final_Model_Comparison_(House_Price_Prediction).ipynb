# %% [markdown]
# ## **comparison table**

# %%
import pandas as pd

results = pd.DataFrame({
    "Model": [
        "Linear Regression",
        "Polynomial Regression",
        "Ridge Regression",
        "Lasso Regression",
        "Elastic Net"
    ],
    "MAE": [0.5016, 0.4240, 0.5016, 0.5036, 0.5687],
    "RMSE": [0.6814, 0.6013, 0.6814, 0.6840, 0.7557],
    "R2 Score": [0.6456, 0.7240, 0.6456, 0.6429, 0.5642]
})

results
# Out:
#                    Model     MAE    RMSE  R2 Score
# 0      Linear Regression  0.5016  0.6814    0.6456
# 1  Polynomial Regression  0.4240  0.6013    0.7240
# 2       Ridge Regression  0.5016  0.6814    0.6456
# 3       Lasso Regression  0.5036  0.6840    0.6429
# 4            Elastic Net  0.5687  0.7557    0.5642

# %% [markdown]
# ### **Conclusion:**
#
# **Polynomial Regression achieved the best performance** with the **lowest error** and **highest R² score.**
# This indicates that **house prices have non-linear relationships with features like income, location, and rooms.**
